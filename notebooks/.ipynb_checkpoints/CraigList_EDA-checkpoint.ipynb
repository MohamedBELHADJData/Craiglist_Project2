# %% [markdown]
# # 🚗 Craigslist Car Listings - Explore and Clean the data
#
#
# After scraping Craiglist in the previous notebook, we are now going to **explore**, **clean** and **analyse** the **data collected**.

# %% [markdown]
# ## Import the dataset
#
# Let's have a quick **overview of the dataset** to see what are we dealing with.

# %%
import pandas as pd

df = pd.read_csv("../data/all-vehicles-model__enriched.csv")
df = df.drop_duplicates(subset='url')

df.head()
# Out:
#                                                  url  \
# 0  https://atlanta.craigslist.org/atl/ctd/d/alpha...
# 1  https://atlanta.craigslist.org/atl/ctd/d/alpha...
# 3  https://atlanta.craigslist.org/atl/ctd/d/alpha...
# 4  https://atlanta.craigslist.org/atl/ctd/d/alpha...
# 5  https://atlanta.craigslist.org/atl/ctd/d/alpha...
#
#                          title   price    location  year          makemodel  \
# 0  2006 Toyota Tundra Crew Cab  $8,990  Alpharetta  2006    TOYOTATUNDRASR5
# 1   2007 Nissan Titan Crew Cab  $7,990  Alpharetta  2007        NISSANTITAN
# 3            2007 Toyota Prius  $3,990  Alpharetta  2007        TOYOTAPRIUS
# 4            2008 Toyota Prius  $2,690  Alpharetta  2008        TOYOTAPRIUS
# 5      2012 Honda Civic Hybrid  $7,990  Alpharetta  2012  HONDACIVICHYBRIDL
#
#   condition    cylinders drive    fuel  ...        Fuel Type1  \
# 0       NaN  8 cylinders   rwd     gas  ...  Regular Gasoline
# 1       NaN  8 cylinders   rwd     gas  ...  Regular Gasoline
# 3       NaN  4 cylinders   fwd  hybrid  ...  Regular Gasoline
# 4       NaN  4 cylinders   fwd  hybrid  ...  Regular Gasoline
# 5       NaN  4 cylinders   fwd  hybrid  ...  Regular Gasoline
#
#                        Transmission          Vehicle Size Class  \
# 0                   Automatic 5-spd  Standard Pickup Trucks 4WD
# 1                   Automatic 5-spd  Standard Pickup Trucks 4WD
# 3  Automatic (variable gear ratios)                Midsize Cars
# 4  Automatic (variable gear ratios)                Midsize Cars
# 5  Automatic (variable gear ratios)                Compact Cars
#
#   Unrounded Combined Mpg For Fuel Type1 Annual Fuel Cost For Fuel Type1  \
# 0                                0.0000                          3600.0
# 1                                0.0000                          3850.0
# 3                                0.0000                          1150.0
# 4                                0.0000                          1150.0
# 5                               43.6569                          1200.0
#
#   GHG Score Unrounded Highway Mpg For Fuel Type1 ATV Type Electric motor  \
# 0       NaN                                0.000      NaN            NaN
# 1       NaN                                0.000      NaN            NaN
# 3       NaN                                0.000   Hybrid            NaN
# 4       NaN                                0.000   Hybrid     202V Ni-MH
# 5       NaN                               44.473   Hybrid    144V Li-Ion
#
#   Start-Stop
# 0        NaN
# 1        NaN
# 3          Y
# 4          Y
# 5          Y
#
# [5 rows x 32 columns]

# %% [markdown]
# By inspecting the structure of the listing URLs, I noticed a consistent pattern that allows us to infer whether a post was created by a **private owner** or a **dealer**.
#
# The logic is based on the URL segment just before `/d/`, which typically follows one of these two formats:
#
# - `cto` → **Owner**
# - `ctd` → **Dealer**
#
# This pattern can be extracted and mapped accordingly to create a new `seller` column in the dataset.

# %%
df.insert(2, 'seller', df['url'].str.extract(r'/([a-z]+)/d/')[0].map({'cto': 'owner', 'ctd': 'dealer'}))

# %% [markdown]
# ## Global Distribution

# %%
df.describe(include='all')
# Out:
#                                                       url  \
# count                                               91196
# unique                                              91196
# top     https://atlanta.craigslist.org/atl/ctd/d/alpha...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                               title  seller   price           location  \
# count                         91195   91196   85403              79176
# unique                        60347       2    9816               7502
# top     500 down - No Credit needed  dealer  $6,500  Est. payment OAC†
# freq                            168   71003     588               1026
# mean                            NaN     NaN     NaN                NaN
# std                             NaN     NaN     NaN                NaN
# min                             NaN     NaN     NaN                NaN
# 25%                             NaN     NaN     NaN                NaN
# 50%                             NaN     NaN     NaN                NaN
# 75%                             NaN     NaN     NaN                NaN
# max                             NaN     NaN     NaN                NaN
#
#                 year makemodel  condition    cylinders  drive  ...  \
# count   91196.000000     91190      48981        63751  67979  ...
# unique           NaN     12978          6            8      3  ...
# top              NaN  FORDF150  excellent  4 cylinders    4wd  ...
# freq             NaN      1934      28910        24259  29259  ...
# mean     2012.601989       NaN        NaN          NaN    NaN  ...
# std        11.844073       NaN        NaN          NaN    NaN  ...
# min      1900.000000       NaN        NaN          NaN    NaN  ...
# 25%      2010.000000       NaN        NaN          NaN    NaN  ...
# 50%      2015.000000       NaN        NaN          NaN    NaN  ...
# 75%      2019.000000       NaN        NaN          NaN    NaN  ...
# max      2026.000000       NaN        NaN          NaN    NaN  ...
#
#               Fuel Type1    Transmission Vehicle Size Class  \
# count              48698           48698              48698
# unique                 7              35                 30
# top     Regular Gasoline  Automatic (S6)       Midsize Cars
# freq               34073            6802               8225
# mean                 NaN             NaN                NaN
# std                  NaN             NaN                NaN
# min                  NaN             NaN                NaN
# 25%                  NaN             NaN                NaN
# 50%                  NaN             NaN                NaN
# 75%                  NaN             NaN                NaN
# max                  NaN             NaN                NaN
#
#        Unrounded Combined Mpg For Fuel Type1 Annual Fuel Cost For Fuel Type1  \
# count                           48698.000000                    48698.000000
# unique                                   NaN                             NaN
# top                                      NaN                             NaN
# freq                                     NaN                             NaN
# mean                               21.173080                     2559.375128
# std                                18.667416                      791.054641
# min                                 0.000000                        0.000000
# 25%                                15.853300                     2050.000000
# 50%                                21.717300                     2550.000000
# 75%                                26.821800                     3000.000000
# max                               140.560300                     6750.000000
#
#            GHG Score Unrounded Highway Mpg For Fuel Type1 ATV Type  \
# count   33650.000000                         48698.000000     8766
# unique           NaN                                  NaN        8
# top              NaN                                  NaN      FFV
# freq             NaN                                  NaN     3205
# mean        5.479049                            24.218251      NaN
# std         1.890944                            18.699469      NaN
# min         1.000000                             0.000000      NaN
# 25%         4.000000                            18.877000      NaN
# 50%         5.000000                            25.998700      NaN
# 75%         7.000000                            32.148300      NaN
# max        10.000000                           131.999100      NaN
#
#        Electric motor Start-Stop
# count            4329      34397
# unique            128          2
# top        202V Ni-MH          N
# freq              752      22122
# mean              NaN        NaN
# std               NaN        NaN
# min               NaN        NaN
# 25%               NaN        NaN
# 50%               NaN        NaN
# 75%               NaN        NaN
# max               NaN        NaN
#
# [11 rows x 33 columns]

# %% [markdown]
# The `describe()` method provides valuable insights into the dataset:
#
# - We have a total of **91,196 unique listings**.
#   All of them have a `title`, but titles may be redundant or duplicated.
#   → We'll use the `URL` **as a unique identifier** for each listing.
#
# - The `condition` column has **many missing values**.
#   Approximately **50%** of the listings do **not** provide this information.
#
# - The **`top` row** indicates the most frequently occurring value for each column.
#   It highlights that, out of 91,196 listings:
#
#   - **28,910 cars** are rated as **_"excellent"_** condition.
#   - **21,911 cars** are **_"white"_**.
#   - **29,259 cars** have **_"4wd"_** drivetrain.
#   - **21,911 cars** are equipped with a **_"4 cylinders"_** engine.
#   - **25,211 listings** are **SUVs**.
#   - Most cars:
#     - Use **_"gas"_** as fuel
#     - Have an **_"automatic"_** transmission
#     - Hold a **_"clean"_** title.
#
#
#
# - Aside from `year`, all features are currently interpreted as text.
#   To perform proper analysis, we'll need to convert the following columns to numeric types:
#   - `price`
#   - `odometer`

# %%
df['price'] = pd.to_numeric(df['price'].str.replace(r'[\$,]', '', regex=True).replace('', pd.NA), errors='coerce').astype('Int64')
df['odometer'] = pd.to_numeric(df['odometer'].str.replace(r'[\,]', '', regex=True).replace('', pd.NA), errors='coerce').astype('Int64')
df['age'] = 2025 - df['year'] 
df.describe(include='all')
# Out:
#                                                       url  \
# count                                               91196
# unique                                              91196
# top     https://atlanta.craigslist.org/atl/ctd/d/alpha...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                               title  seller          price           location  \
# count                         91195   91196        85403.0              79176
# unique                        60347       2           <NA>               7502
# top     500 down - No Credit needed  dealer           <NA>  Est. payment OAC†
# freq                            168   71003           <NA>               1026
# mean                            NaN     NaN   23185.138075                NaN
# std                             NaN     NaN  601389.870412                NaN
# min                             NaN     NaN            0.0                NaN
# 25%                             NaN     NaN         7500.0                NaN
# 50%                             NaN     NaN        14700.0                NaN
# 75%                             NaN     NaN        25434.0                NaN
# max                             NaN     NaN    123456789.0                NaN
#
#                 year makemodel  condition    cylinders  drive  ...  \
# count   91196.000000     91190      48981        63751  67979  ...
# unique           NaN     12978          6            8      3  ...
# top              NaN  FORDF150  excellent  4 cylinders    4wd  ...
# freq             NaN      1934      28910        24259  29259  ...
# mean     2012.601989       NaN        NaN          NaN    NaN  ...
# std        11.844073       NaN        NaN          NaN    NaN  ...
# min      1900.000000       NaN        NaN          NaN    NaN  ...
# 25%      2010.000000       NaN        NaN          NaN    NaN  ...
# 50%      2015.000000       NaN        NaN          NaN    NaN  ...
# 75%      2019.000000       NaN        NaN          NaN    NaN  ...
# max      2026.000000       NaN        NaN          NaN    NaN  ...
#
#           Transmission  Vehicle Size Class  \
# count            48698               48698
# unique              35                  30
# top     Automatic (S6)        Midsize Cars
# freq              6802                8225
# mean               NaN                 NaN
# std                NaN                 NaN
# min                NaN                 NaN
# 25%                NaN                 NaN
# 50%                NaN                 NaN
# 75%                NaN                 NaN
# max                NaN                 NaN
#
#        Unrounded Combined Mpg For Fuel Type1 Annual Fuel Cost For Fuel Type1  \
# count                           48698.000000                    48698.000000
# unique                                   NaN                             NaN
# top                                      NaN                             NaN
# freq                                     NaN                             NaN
# mean                               21.173080                     2559.375128
# std                                18.667416                      791.054641
# min                                 0.000000                        0.000000
# 25%                                15.853300                     2050.000000
# 50%                                21.717300                     2550.000000
# 75%                                26.821800                     3000.000000
# max                               140.560300                     6750.000000
#
#            GHG Score Unrounded Highway Mpg For Fuel Type1 ATV Type  \
# count   33650.000000                         48698.000000     8766
# unique           NaN                                  NaN        8
# top              NaN                                  NaN      FFV
# freq             NaN                                  NaN     3205
# mean        5.479049                            24.218251      NaN
# std         1.890944                            18.699469      NaN
# min         1.000000                             0.000000      NaN
# 25%         4.000000                            18.877000      NaN
# 50%         5.000000                            25.998700      NaN
# 75%         7.000000                            32.148300      NaN
# max        10.000000                           131.999100      NaN
#
#        Electric motor Start-Stop           age
# count            4329      34397  91196.000000
# unique            128          2           NaN
# top        202V Ni-MH          N           NaN
# freq              752      22122           NaN
# mean              NaN        NaN     12.398011
# std               NaN        NaN     11.844073
# min               NaN        NaN     -1.000000
# 25%               NaN        NaN      6.000000
# 50%               NaN        NaN     10.000000
# 75%               NaN        NaN     15.000000
# max               NaN        NaN    125.000000
#
# [11 rows x 34 columns]

# %% [markdown]
# Let's define a **quick way to explore** how a **number** (like price or mileage) behaves across different **categories** (like car color or engine).
#
# - Groups the data by a category we choose (`col1`)
# - Calculates an average (or median, sum, etc.) of a number column (`col2`)
# - Plots:
#   - A **bar chart** showing the aggregated value for each category
#   - A **line chart** showing how many listings fall into each category

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_bar_and_count_line(df, col1, col2, agg_func='mean'):
    """
    Plots a bar chart of an aggregated numeric column (col2) and a line chart
    representing the count of each category in col1.

    Parameters:
    - df: pandas DataFrame
    - col1: str, categorical column (used as x-axis)
    - col2: str, numerical column to aggregate (bar chart)
    - agg_func: str, aggregation function for col2 (e.g. 'mean', 'median', 'sum')
    """
    # Group and aggregate
    grouped = df.groupby(col1).agg(
        aggregated_value=(col2, agg_func),
        count=(col2, 'count')
    ).sort_values('aggregated_value', ascending=False)

    # Plot
    fig, ax1 = plt.subplots(figsize=(12, 6))

    color1 = 'tab:blue'
    ax1.set_xlabel(col1)
    ax1.set_ylabel(f"{agg_func.title()} of {col2}", color=color1)
    sns.barplot(x=grouped.index, y=grouped['aggregated_value'], ax=ax1)
    ax1.tick_params(axis='y', labelcolor=color1)
    plt.setp(ax1.get_xticklabels(), rotation=45)

    ax2 = ax1.twinx()
    color2 = 'tab:red'
    ax2.set_ylabel(f"Count of cars", color=color2)
    sns.lineplot(x=grouped.index, y=grouped['count'], ax=ax2, color=color2, marker='o')
    ax2.tick_params(axis='y', labelcolor=color2)

    plt.title(f"{agg_func.title()} of {col2} and count of cars")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# - It helps spot which categories are common vs. rare
# - Lets you see which groups are more expensive, cheaper, etc.
# - Great for data exploration and figuring out if a column is useful, noisy, or unbalanced
#
# We can use it to see the **average price by city**:

# %%
plot_bar_and_count_line(df, col1='region', col2='price', agg_func='mean')

# %% [markdown]
# We can see that the **average price** is way to big for *San Francisco*. Let's check the **median**.

# %%
plot_bar_and_count_line(df, col1='region', col2='price', agg_func='median')

# %% [markdown]
# The **median** seems normal, we can have a look at the highest price for San Francisco and try to understand what is behind.

# %%
df[df['region'].str.lower() == 'sfbay'].sort_values('price', ascending=False).head(10)
# Out:
#                                                       url  \
# 149326  https://sfbay.craigslist.org/sfc/ctd/d/hayward...
# 149327  https://sfbay.craigslist.org/sfc/ctd/d/hayward...
# 139303  https://sfbay.craigslist.org/eby/ctd/d/henders...
# 138042  https://sfbay.craigslist.org/eby/ctd/d/concord...
# 146946  https://sfbay.craigslist.org/sby/ctd/d/san-jos...
# 142866  https://sfbay.craigslist.org/eby/cto/d/union-c...
# 139302  https://sfbay.craigslist.org/eby/ctd/d/henders...
# 150670  https://sfbay.craigslist.org/sfc/ctd/d/san-jos...
# 146757  https://sfbay.craigslist.org/sby/ctd/d/san-jos...
# 144845  https://sfbay.craigslist.org/pen/ctd/d/san-bru...
#
#                                                     title  seller      price  \
# 149326  All hond toyota Nissan all makes admodels. We ...  dealer  123456789
# 149327  Toyota sienna Camry Prius RAV4 Corolla Tacoma ...  dealer  123456789
# 139303               1971 Ferrari Daytona Coupe SKU:C1049  dealer     795980
# 138042  2017 Lamborghini Aventador LP 750-4 SV * RYFT ...  dealer     455888
# 146946                                    Ferrari 488 GTB  dealer     260000
# 142866  Wanted classic vehicles, American European Por...   owner     250000
# 139302    1968 Ford Shelby Cobra GT500 Fastback SKU:C1060  dealer     249980
# 150670  2025 Land Rover Range Rover suv Icy White SV B...  dealer     237780
# 146757             2021 Lamborghini Urus Base AWD 4dr SUV  dealer     220000
# 144845                                  2018 McLaren 720s  dealer     220000
#
#                                                  location  year  \
# 149326  2000 2001 2002 2003 2004 2005 2006 2007 2008 2...  2007
# 149327  2000 2001 2002 2003 2004 2005 2006 2007 2008 2...  2007
# 139303                               danville / san ramon  1971
# 138042                                                NaN  2017
# 146946                                           San Jose  2018
# 142866                                         Union city  1967
# 139302                               danville / san ramon  1968
# 150670                 CALL 415-226-6803 FOR AVAILABILITY  2025
# 146757                                         + Car Time  2021
# 144845                                          san bruno  2018
#
#                                             makemodel  condition  \
# 149326                              HONDATOYOTANISSAN        NaN
# 149327                             SIENNACAMRYCOROLLA        NaN
# 139303                            FERRARIDAYTONACOUPE        NaN
# 138042  LAMBORGHINIAVENTADORLP7504SVRYFTWHITEROADSTER        NaN
# 146946                                        FERRARI   like new
# 142866                            FORDMUSTANGFASTBACK        NaN
# 139302                                    FORDMUSTANG        NaN
# 150670                               LANDROVERRANGESV       good
# 146757                                LAMBORGHINIURUS        NaN
# 144845                                    MCLAREN720S  excellent
#
#            cylinders drive  ...       Transmission  Vehicle Size Class  \
# 149326           NaN   NaN  ...                NaN                 NaN
# 149327           NaN   NaN  ...                NaN                 NaN
# 139303           NaN   NaN  ...                NaN                 NaN
# 138042  12 cylinders   4wd  ...  Automatic (AM-S7)         Two Seaters
# 146946   8 cylinders   rwd  ...                NaN                 NaN
# 142866           NaN   NaN  ...                NaN                 NaN
# 139302           NaN   NaN  ...                NaN                 NaN
# 150670           NaN   NaN  ...                NaN                 NaN
# 146757           NaN   NaN  ...                NaN                 NaN
# 144845   8 cylinders   rwd  ...                NaN                 NaN
#
#        Unrounded Combined Mpg For Fuel Type1 Annual Fuel Cost For Fuel Type1  \
# 149326                                   NaN                             NaN
# 149327                                   NaN                             NaN
# 139303                                   NaN                             NaN
# 138042                               13.1199                          5200.0
# 146946                                   NaN                             NaN
# 142866                                   NaN                             NaN
# 139302                                   NaN                             NaN
# 150670                                   NaN                             NaN
# 146757                                   NaN                             NaN
# 144845                                   NaN                             NaN
#
#        GHG Score Unrounded Highway Mpg For Fuel Type1 ATV Type Electric motor  \
# 149326       NaN                                  NaN      NaN            NaN
# 149327       NaN                                  NaN      NaN            NaN
# 139303       NaN                                  NaN      NaN            NaN
# 138042       1.0                              18.4729      NaN            NaN
# 146946       NaN                                  NaN      NaN            NaN
# 142866       NaN                                  NaN      NaN            NaN
# 139302       NaN                                  NaN      NaN            NaN
# 150670       NaN                                  NaN      NaN            NaN
# 146757       NaN                                  NaN      NaN            NaN
# 144845       NaN                                  NaN      NaN            NaN
#
#        Start-Stop age
# 149326        NaN  18
# 149327        NaN  18
# 139303        NaN  54
# 138042          Y   8
# 146946        NaN   7
# 142866        NaN  58
# 139302        NaN  57
# 150670        NaN   0
# 146757        NaN   4
# 144845        NaN   7
#
# [10 rows x 34 columns]

# %% [markdown]
# The first two rows appear to be clear anomalies.
# The remaining ones mostly correspond to genuinely expensive cars — brands like Ferrari, Lamborghini, Range Rover, McLaren, Rolls-Royce, etc.
#
# To reduce noise and keep the dataset consistent, we’ll apply the following price filters:
#
# * Remove all listings priced above **$1,000,000**
#
# * Remove all listings priced below **$2,500**
#
# ---
#
# Following the same logic as with price filtering, we’ll now apply additional rules to clean up the dataset:
#
# - Remove all listings where the **year is not between 1985 and 2025**
# - Remove all listings where the **odometer reading is above 350,000 miles** or **below 5 miles**

# %%
df = df[(df['price'] >= 2500) & (df['price'] < 1000000)]
df = df[(df['year'] >= 1985) & (df['year'] <= 2025)]
df = df[(df['odometer'] >= 5) & (df['odometer'] <= 350000)]

# %%
plot_bar_and_count_line(df, col1='region', col2='price', agg_func='mean')

# %% [markdown]
# ## Distribution by Categorical columns

# %%
import matplotlib.pyplot as plt

categories = ['make_mapped','seller', 'condition', 'cylinders', 'drive', 'fuel', 'paint_color', 'transmission', 'type']

for cat in categories:
    counts = df[cat].dropna().value_counts()
    total = counts.sum()
    
    def plot_top_10_pie(df, cat):
        counts = df[cat].value_counts()
        total = counts.sum()

    # Séparation des 10 plus fréquents et du reste
    top10 = counts.nlargest(10)
    other = total - top10.sum()
    counts_top10 = pd.concat([top10, pd.Series({'Other': other})])

    def autopct_format(pct):
        absolute = int(round(pct * total / 100))
        return f"{pct:.1f}%\n({absolute})"

    plt.figure(figsize=(6, 6))
    wedges, texts, autotexts = plt.pie(
        counts_top10,
        labels=counts_top10.index,
        autopct=autopct_format,
        startangle=140,
        textprops={'fontsize': 9}
    )

    plt.title(f'Distribution of {cat}')
    plt.axis('equal')
    plt.show()

# %% [markdown]
# ## Distribution by Numerical columns

# %%
sample_df = df.sample(n=5000, random_state=42)

sns.pairplot(sample_df[['price', 'odometer', 'age']], plot_kws={'alpha': 0.1, 's': 10})
plt.suptitle("Scatter matrix sampled data", y=1.02)
plt.show()

# %% [markdown]
# After cleaning and sampling the dataset, we can visualize the scatter matrix of the numerical variables (`price`, `odometer`, `year`).
#
# Here are the main takeaways:
#
# - **Price vs Odometer**: We observe a clear **negative relationship** — more expensive cars tend to have lower mileage.
# - **Price vs Age**: There’s a visible **negative correlation** — newer cars generally cost more.
# - **Odometer vs Age**: A **strong relationship** — older vehicles naturally have higher mileage.
# - A few **outliers** remain (e.g., older cars with very low mileage), but they are limited.
#
# ---
#
#
# To complement this visual inspection, we’ll now compute and plot a **correlation heatmap**.
# This will help us quantify the linear relationships between the numerical features and validate the trends we’ve observed visually.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

num_cols = ['price', 'odometer', 'age']

corr_matrix = df[num_cols].corr()

# Affichage de la heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# The heatmap reveals meaningful relationships between the numerical variables in the dataset:
#
# - **Price vs Odometer** → **-0.46**
#   There's a moderate negative correlation: **the more a car has been driven, the lower its price** tends to be.
#
# - **Price vs Age** → **-0.36**
#   As expected, **older cars tend to be less expensive**, though the correlation is slightly weaker than with odometer.
#
# - **Odometer vs Age** → **+0.44**
#   A positive correlation showing that **older cars generally have more mileage**.
#
# These results confirm the logic we’d expect in the used car market, and also validate the cleaning process we applied earlier.

# %%
# Table de fréquence : (region, marque)
region_make_counts = df.groupby(['region', 'make_mapped']).size().unstack(fill_value=0)

# Trier les régions par volume total décroissant
region_order = region_make_counts.sum(axis=1).sort_values(ascending=False).index
region_make_counts = region_make_counts.loc[region_order]

# Garder les 10 marques les plus fréquentes globalement
top_makes = region_make_counts.sum(axis=0).sort_values(ascending=False).head(15).index
heatmap_data = region_make_counts[top_makes]

# Affichage de la heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, fmt='d', cmap='Blues')
plt.title("Nombre d'occurrences de chaque marque par région (régions triées par volume)")
plt.xlabel("Marque (make_mapped)")
plt.ylabel("Région")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calcul du prix moyen par region et make
region_make_price = df.groupby(['region', 'model'])['price'].mean().unstack()

# Conversion explicite en float et gestion des NaN
region_make_price = region_make_price.astype(float)

# Tri des régions par nombre total d'annonces (pour avoir les plus "actives" en haut)
region_order = df.groupby('region').size().sort_values(ascending=False).index
region_make_price = region_make_price.loc[region_order]

# Garder uniquement les 10 marques les plus fréquentes
top_makes = df['model'].value_counts().head(10).index
heatmap_data = region_make_price[top_makes]

# Drop des régions complètement vides (si aucune des top marques présentes)
heatmap_data = heatmap_data.dropna(how='all')

# Affichage
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap='YlGnBu')
plt.title("Prix moyen par marque et par région")
plt.xlabel("Marque (make_mapped)")
plt.ylabel("Région")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Nettoyage des prix
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# Moyenne des prix par région et marque
region_make_price = df.groupby(['region', 'make_mapped'])['price'].mean().unstack()

# Top 10 marques les plus chères en moyenne
top_makes = df.groupby('make_mapped')['price'].mean().sort_values(ascending=False).head(10).index

# Filtrage
heatmap_data = region_make_price[top_makes]

# Ordre des régions par volume décroissant
region_order = df['region'].value_counts().index
heatmap_data = heatmap_data.loc[region_order]

# Nettoyage des lignes vides
heatmap_data = heatmap_data.dropna(how='all')

# 💥 Fix: convertir en float explicite pour seaborn
heatmap_data = heatmap_data.astype(float)

# Affichage
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap='YlGnBu')
plt.title("Prix moyen par région pour les 10 marques les plus chères")
plt.xlabel("Marque (make_mapped)")
plt.ylabel("Région")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assurer que 'price' et 'year' sont numériques
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['year'] = pd.to_numeric(df['year'], errors='coerce')

# Filtrer sur les voitures dont l'année > 2015
df_recent = df[(df['year'] > 2015) & df['model'].notna() & df['price'].notna()]

# Calculer le prix moyen par marque
avg_price_by_make = df_recent.groupby('model')['price'].mean()

# Prendre les 30 marques les plus chères
top30_expensive = avg_price_by_make.sort_values(ascending=False).head(30)

# Plot
plt.figure(figsize=(12, 10))
sns.barplot(x=top30_expensive.values, y=top30_expensive.index, palette='magma')

plt.xlabel("Prix moyen ($)")
plt.ylabel("Marque")
plt.title("Top 30 marques avec le prix moyen le plus élevé (année > 2015)")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Mohamed\AppData\Local\Temp\ipykernel_7272\2216315395.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top30_expensive.values, y=top30_expensive.index, palette='magma')

# %%
df.columns
# Out:
# Index(['url', 'title', 'seller', 'price', 'location', 'year', 'makemodel',
#        'condition', 'cylinders', 'drive', 'fuel', 'odometer', 'paint_color',
#        'title_status', 'transmission', 'type', 'region', 'make_mapped',
#        'makemodel_withoutmake', 'specific_model', 'model', 'Year',
#        'Engine displacement', 'Fuel Type1', 'Transmission',
#        'Vehicle Size Class', 'Unrounded Combined Mpg For Fuel Type1',
#        'Annual Fuel Cost For Fuel Type1', 'GHG Score',
#        'Unrounded Highway Mpg For Fuel Type1', 'ATV Type', 'Electric motor',
#        'Start-Stop', 'age'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# S'assurer que les colonnes sont bien numériques
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['Engine displacement'] = pd.to_numeric(df['Engine displacement'], errors='coerce')

# Supprimer les lignes avec des valeurs manquantes
df_corr = df.dropna(subset=['price', 'cylinders'])

# Calcul de la corrélation
correlation = df_corr['price'].corr(df_corr['Engine displacement'])
print(f"Corrélation entre prix et Engine displacement : {correlation:.3f}")

# Nuage de points avec régression
plt.figure(figsize=(10, 6))
sns.regplot(
    data=df_corr,
    x='Engine displacement',
    y='price',
    scatter_kws={'alpha': 0.3},
    line_kws={'color': 'red'}
)

plt.title(f"Corrélation entre prix et Engine displacement (r = {correlation:.2f})")
plt.xlabel("Engine displacement (litres)")
plt.ylabel("Prix ($)")
plt.tight_layout()
plt.show()
# Out:
# Corrélation entre prix et Engine displacement : 0.239

# %%
df_clean = df[['model', 'Engine displacement']].copy()
df_clean['Engine displacement'] = pd.to_numeric(df_clean['Engine displacement'], errors='coerce')
df_clean = df_clean.dropna()
df_clean.sort_values('Engine displacement', ascending=False).drop_duplicates('model').head(20)
# Out:
#                 model  Engine displacement
# 21474           VIPER                  8.0
# 1321         CORVETTE                  7.0
# 84052        MULSANNE                  6.8
# 30651          ARNAGE                  6.8
# 65596         PHANTOM                  6.7
# 39028        CULLINAN                  6.7
# 65602          WRAITH                  6.6
# 65943            DAWN                  6.6
# 75504           GHOST                  6.6
# 66630       AVENTADOR                  6.5
# 147934         SIERRA                  6.5
# 33553      CHALLENGER                  6.4
# 33756   GRANDCHEROKEE                  6.4
# 149916        CHARGER                  6.4
# 84702         DURANGO                  6.4
# 112936  GRANDWAGONEER                  6.4
# 36720              FF                  6.3
# 152114       CLSCLASS                  6.3
# 36050       GTC4LUSSO                  6.3
# 55899        ESCALADE                  6.2
